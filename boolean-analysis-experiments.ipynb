# %%
import black
import jupyter_black

jupyter_black.load(
    lab=False,
    line_length=79,
    target_version=black.TargetVersion.PY39,
)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import lattice_symmetries as ls
from ipywidgets import interact, interact_manual, IntSlider, FloatSlider
from sklearn.metrics import accuracy_score
from tqdm import tqdm

from heisenberg_hamiltonians import HeisenbergJ1J2, batched_state_info_df

from spin_lattices import (
    ChainLattice,
    SquareLattice,
    KagomeLattice,
)

from scipy.stats import entropy
from boolean_analysis import (
    get_fourier_transform_matrix,
    calculate_fourier_transform_matrix,
    BooleanFourierAnalyser,
    SignalOption,
)

from itertools import product
import seaborn as sns

# %matplotlib inline

# %%
fourier_transform_matrix_cache = {}
BooleanFourierAnalyser(
    system=HeisenbergJ1J2(
        SquareLattice(width=4, height=4),
        J1=1,
        J2=0,
        use_symmetries=True,
        spin_inversion=1,
    ),
    fourier_transform_matrix_cache=fourier_transform_matrix_cache,
    use_symmetries=True,
    eigenstates=10,
).predict(SignalOption(eigenstate=0), keep_first=26)
# Out:
# self.number_spins=16
# Symmetry group contains 128 elements
# Hilbert space dimension is 107
# Fourier transform matrix found at fourier-bases/fourier_transform_matrix-e2331588b59edde2054e2712731baf69.feather
# Finding system ground state
# Using cached version of eigenvalues / eigenstates from groundstates/HeisenbergJ1J2-SquareLattice4x4-1.0-0.0-True-1-10.pickle
# Ground state energy is -44.9139328337
# array([ 0.95269775,  0.69891357, -0.69891357, ..., -0.69891357,
#         0.69891357,  0.95269775])

# %%
eigenstates = 10

lattices = {
    "square4x4": SquareLattice(width=4, height=4),
    "kagome2x2": KagomeLattice(width=2, height=2),
}
J2values = np.arange(0.0, 1.0, 0.1)

analyzers = {
    (J2, lat_name): BooleanFourierAnalyser(
        system=HeisenbergJ1J2(
            lattice,
            J1=1,
            J2=J2,
            use_symmetries=True,
            spin_inversion=1,
        ),
        fourier_transform_matrix_cache=fourier_transform_matrix_cache,
        use_symmetries=True,
        eigenstates=eigenstates,
    )
    for J2 in tqdm(J2values)
    for lat_name, lattice in (lattices.items())
}
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# self.number_spins=16
# Symmetry group contains 128 elements
# Hilbert space dimension is 107
# Found cached fourier basis, will use it
# Finding system ground state
# Using cached version of eigenvalues / eigenstates from groundstates/HeisenbergJ1J2-SquareLattice4x4-1.0-0.0-True-1-10.pickle
# Ground state energy is -44.9139328337
# self.number_spins=12
# Symmetry group contains 16 elements
# Hilbert space dimension is 47
#  10%|█         | 1/10 [00:00<00:04,  1.86it/s]
# Fourier transform matrix found at fourier-bases/fourier_transform_matrix-844997e7d35cf64703236336e7a64b06.feather
# Finding system ground state
# Using cached version of eigenvalues / eigenstates from groundstates/HeisenbergJ1J2-KagomeLattice2x2-1.0-0.0-True-1-10.pickle
# Ground state energy is -23.2969224448
# self.number_spins=16
# Symmetry group contains 128 elements
# Hilbert space dimension is 107
# Found cached fourier basis, will use it
# Finding system ground state
# ...

# %%
analyzer = analyzers[0.1, "kagome2x2"]
eigenstate = 0
keep_first = 1
accuracy_score(
    np.sign(
        analyzer.predict(
            SignalOption("sign", eigenstate), keep_first=keep_first
        )
    ),
    np.sign(
        analyzer.system.get_df_eigenstate(k=eigenstate, canonical_basis=True)[
            "eigenstate_coeff"
        ]
    ),
),
# Out:
# (1.0,)

# %%
(analyzer.system.eigenstates[:, 0] ** 2).sum()
# Out:
# 0.9999999999999968

# %%
analyzer.get_spectre_df(
    SignalOption(eigenstate=0, weighted=True),
).sum()
# Out:
# coeff         2.211977
# abs_coeff    10.590358
# dtype: float64

# %%
def get_all_time_top_subsets(analyzers, lat_name, top, eigenstate=0):
    subsets = set([])
    for J2 in tqdm(J2values):
        analyzer = analyzers[J2, lat_name]
        spectre_df = analyzer.get_spectre_df(
            SignalOption(eigenstate=eigenstate, weighted=True),
        )
        subsets.update(spectre_df.iloc[:top].index)
    return subsets

# %%
len(get_all_time_top_subsets(analyzers, "square4x4", 10))
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  6.26it/s]
# 32

# %%
def plot_top_state_coeffs(
    analyzers,
    lat_name,
    top,
    eigenstate=0,
    keep_first_accuracy=(1, 2, 5, 10),
    y="abs_coeff",
    plot_top_subsets=5,
):
    subsets = list(
        get_all_time_top_subsets(analyzers, lat_name, top, eigenstate)
    )
    data = []
    for J2 in J2values:
        spectre = analyzers[J2, lat_name].get_spectre_df(
            SignalOption(eigenstate=eigenstate, weighted=True),
        )
        data.append(
            spectre.loc[subsets]
            .reset_index()
            .rename(columns={"index": "state"})
            .assign(state=lambda x: x["state"].astype(str))
            .assign(J2=J2)
        )
    df = pd.concat(data, axis=0)

    fig = plt.figure(tight_layout=True, figsize=(13, 8))
    axd = fig.subplot_mosaic(
        [
            ["coeffs"] * plot_top_subsets,
            ["accuracy"] * plot_top_subsets,
            [f"state{i}" for i in range(plot_top_subsets)],
        ]
    )
    axd["accuracy"].sharex(axd["coeffs"])
    for i in range(1, plot_top_subsets):
        axd[f"state{i}"].sharey(axd["state0"])

    # ax1.set_yscale("log")
    sns.lineplot(data=df, x="J2", y=y, hue="state", ax=axd["coeffs"])

    accuracy_data = []
    for J2 in J2values:
        analyzer = analyzers[J2, lat_name]
        keep_first = 10
        # for keep_first in keep_first_accuracy:
        for weighted in [True, False]:
            print(f"{J2=}, {keep_first=}, {eigenstate=}")
            accuracy = accuracy_score(
                np.sign(
                    analyzer.predict(
                        SignalOption("sign", eigenstate, weighted=weighted),
                        keep_first=keep_first,
                    )
                ),
                np.sign(
                    analyzer.system.get_df_eigenstate(
                        k=eigenstate, canonical_basis=True
                    )["eigenstate_coeff"]
                ),
            )
            accuracy_data.append(
                {
                    "J2": J2,
                    "accuracy": accuracy,
                    "keep_first": str(keep_first),
                    "weighted": weighted,
                }
            )

    sns.lineplot(
        data=pd.DataFrame(accuracy_data),
        x="J2",
        y="accuracy",
        hue="weighted",
        style="weighted",
        ax=axd["accuracy"],
    )

    def onclick(event):
        J2 = event.xdata
        J2 = J2values[np.argmin(np.abs(J2values - J2))]
        analyzer = analyzers[J2, lat_name]

        multiplicities = (
            batched_state_info_df(
                analyzer.fourier_basis, analyzer.canonical_fourier_basis.states
            )
            .reset_index()
            .rename(columns={"index": "subset"})
            .groupby("representative")
            .size()
        )

        spectre = analyzer.get_spectre_df(
            signal=SignalOption(eigenstate=eigenstate, weighted=True)
        )

        for i in range(plot_top_subsets):
            ax = axd[f"state{i}"]
            ax.clear()

            analyzer.visualize_spectre_support_lattice(
                signal=SignalOption(eigenstate=eigenstate), m=i, ax=ax
            )
            ax.set_title(
                f"{spectre.index[i]} ({multiplicities[spectre.index[i]]})"
            )
            ax.set_ylabel(f"{J2=}")
            ax.set_aspect("equal", "box")

    cid = fig.canvas.mpl_connect("button_press_event", onclick)

    return axd

# %%
# %matplotlib notebook

plot_top_state_coeffs(
    analyzers,
    "kagome2x2",
    top=5,
    eigenstate=0,
    keep_first_accuracy=[1, 2],
    y="abs_coeff",
)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 7665.03it/s]
# <img src="data:image/png;base64,..." width="936">
# J2=0.0, keep_first=10, eigenstate=0
# J2=0.0, keep_first=10, eigenstate=0
# J2=0.1, keep_first=10, eigenstate=0
# J2=0.1, keep_first=10, eigenstate=0
# J2=0.2, keep_first=10, eigenstate=0
# J2=0.2, keep_first=10, eigenstate=0
# J2=0.30000000000000004, keep_first=10, eigenstate=0
# J2=0.30000000000000004, keep_first=10, eigenstate=0
# J2=0.4, keep_first=10, eigenstate=0
# J2=0.4, keep_first=10, eigenstate=0
# J2=0.5, keep_first=10, eigenstate=0
# J2=0.5, keep_first=10, eigenstate=0
# J2=0.6000000000000001, keep_first=10, eigenstate=0
# J2=0.6000000000000001, keep_first=10, eigenstate=0
# J2=0.7000000000000001, keep_first=10, eigenstate=0
# J2=0.7000000000000001, keep_first=10, eigenstate=0
# J2=0.8, keep_first=10, eigenstate=0
# J2=0.8, keep_first=10, eigenstate=0
# J2=0.9, keep_first=10, eigenstate=0
# J2=0.9, keep_first=10, eigenstate=0
# ...

# %%
analyzer = analyzers[0.2, "square4x4"]

# %%
analyzer.predict(SignalOption(eigenstate=1), keep_first=27)
# Out:
# array([-0.33288574,  0.45495605, -0.50805664, ..., -0.50805664,
#         0.45495605, -0.33288574])

# %%
def predict(
    self, signal: SignalOption = SignalOption(), keep_first=None
) -> np.array:
    coeffs = self.get_spectre_df(signal)["coeff"]
    if keep_first is not None:
        coeffs = coeffs.iloc[:keep_first]

    if self.use_symmetries:
        state_info_df = batched_state_info_df(
            self.fourier_basis, self.canonical_fourier_basis.states
        )
        coeffs = state_info_df.join(coeffs, on="representative")[
            "coeff"
        ].dropna()

    if keep_first is None:
        if self.canonical_fourier_transform_matrix is None:
            self.canonical_fourier_transform_matrix = get_fourier_transform_matrix(
                states=self.system.canonical_basis.states,
                subsets=self.canonical_fourier_basis.states,
                number_spins=self.system.number_spins,
                fourier_transform_matrix_cache=self.fourier_transform_matrix_cache,
                show_progress=True,
            )

        coeffs = coeffs.loc[self.canonical_fourier_basis.states]

        return self.canonical_fourier_transform_matrix @ coeffs
    else:
        transform_matrix = get_fourier_transform_matrix(
            states=self.system.canonical_basis.states,
            subsets=np.array(coeffs.index, dtype="uint64"),
            number_spins=self.system.number_spins,
            # fourier_transform_matrix_cache=self.fourier_transform_matrix_cache,
            show_progress=True,
        )

        return transform_matrix @ coeffs

# %%
predict(analyzer, SignalOption(eigenstate=1), keep_first=27)
# Out:
# Fourier transform matrix found at fourier-bases/fourier_transform_matrix-b69174dccaf827469219059a86ce80b9.feather
# array([-0.33288574,  0.45495605, -0.50805664, ..., -0.50805664,
#         0.45495605, -0.33288574])

# %%
analyzer = analyzers[0, "square4x4"]

# %%
for J2 in J2values:
    print(J2)
    analyzers[J2, "square4x4"].predict(
        SignalOption(eigenstate=1), keep_first=26
    )
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9

# %%
plot_top_state_coeffs(
    analyzers, "square4x4", top=5, eigenstate=0, y="abs_coeff"
)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 5848.17it/s]
# <img src="data:image/png;base64,..." width="936">
# J2=0.0, keep_first=1, eigenstate=0
# J2=0.0, keep_first=2, eigenstate=0
# J2=0.0, keep_first=5, eigenstate=0
# J2=0.0, keep_first=10, eigenstate=0
# J2=0.1, keep_first=1, eigenstate=0
# J2=0.1, keep_first=2, eigenstate=0
# J2=0.1, keep_first=5, eigenstate=0
# J2=0.1, keep_first=10, eigenstate=0
# J2=0.2, keep_first=1, eigenstate=0
# J2=0.2, keep_first=2, eigenstate=0
# J2=0.2, keep_first=5, eigenstate=0
# J2=0.2, keep_first=10, eigenstate=0
# J2=0.30000000000000004, keep_first=1, eigenstate=0
# J2=0.30000000000000004, keep_first=2, eigenstate=0
# J2=0.30000000000000004, keep_first=5, eigenstate=0
# J2=0.30000000000000004, keep_first=10, eigenstate=0
# J2=0.4, keep_first=1, eigenstate=0
# J2=0.4, keep_first=2, eigenstate=0
# J2=0.4, keep_first=5, eigenstate=0
# J2=0.4, keep_first=10, eigenstate=0
# J2=0.5, keep_first=1, eigenstate=0
# J2=0.5, keep_first=2, eigenstate=0
# ...

# %%
eigenstates = 3
analyzer = BooleanFourierAnalyser(
    system=HeisenbergJ1J2(
        KagomeLattice(width=2, height=2),
        J1=1,
        J2=0.2,
        use_symmetries=True,
        spin_inversion=1,
    ),
    fourier_transform_matrix_cache=fourier_transform_matrix_cache,
    use_symmetries=True,
    eigenstates=eigenstates,
)
# Out:
# self.number_spins=12
# Symmetry group contains 16 elements
# Hilbert space dimension is 47
# Found cached fourier basis, will use it
# Finding system ground state
# Using cached version of eigenvalues / eigenstates from groundstates/HeisenbergJ1J2-KagomeLattice2x2-1.0-0.2-True-1-10.pickle
# Ground state energy is -21.9239567839

# %%
eigenstate = 0
accuracy_score(
    np.sign(analyzer.predict(SignalOption("sign", eigenstate), keep_first=1)),
    np.sign(
        analyzer.system.get_df_eigenstate(k=eigenstate, canonical_basis=True)[
            "eigenstate_coeff"
        ]
    ),
)
# Out:
# 1.0

# %%
analyzer.visualize_spectre_support_lattice(SignalOption(eigenstate=0))
