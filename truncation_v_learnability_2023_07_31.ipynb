# %%
from truncation_v_learnability_2023_07_31 import output_dir
import pandas as pd
import numpy as np
from misc_utils import read_json_dir_to_df
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 2023-08-01 21:40:14.227 | DEBUG    | lattice_symmetries:__init__:50 - Initializing Haskell runtime...
# 2023-08-01 21:40:14.229 | DEBUG    | lattice_symmetries:__init__:52 - Initializing Chapel runtime...
# 2023-08-01 21:40:14.304 | DEBUG    | lattice_symmetries:__init__:54 - Setting Python exception handler...
# set_python_exception_handler ...

# %%
df = read_json_dir_to_df(output_dir)

# %%
df
# Out:
#          loss  train_accuracy  test_accuracy  epoch  run  non_zero_coeffs  \
# 0    1.660879        0.904702       0.867285    299    1             1225
# 1    1.640742        0.905878       0.874674    299    2             1488
# 2    2.445041        0.854350       0.819459    299    6              437
# 3    2.872407        0.822185       0.779454    299    3              262
# 4    3.030679        0.809886       0.768389    299    5              262
# ..        ...             ...            ...    ...  ...              ...
# 116  2.401700        0.858507       0.823227    299    1              437
# 117  1.826478        0.894008       0.858954    299    4              875
# 118  1.884154        0.892144       0.862685    299    0             1225
# 119  1.606575        0.909488       0.870917    299    1             1400
# 120  2.053881        0.882196       0.852564    299    4              612
#
#                                                system             lattice  \
# 0    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 1    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 2    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 3    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 4    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# ..                                                ...                 ...
# 116  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 117  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 118  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 119  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 120  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
#
#       J2  keep_terms  split  alpha
# 0    1.3        1225     13    2.0
# 1    1.3        1488     16    2.0
# 2    1.3         437      4    2.0
# 3    1.3         262      2    2.0
# 4    1.3         262      2    2.0
# ..   ...         ...    ...    ...
# 116  1.3         437      4    2.0
# 117  1.3         875      9    2.0
# 118  1.3        1225     13    2.0
# 119  1.3        1400     15    2.0
# 120  1.3         612      6    2.0
#
# [121 rows x 12 columns]

# %%
sns.relplot(
    df,
    x="keep_terms",
    y="test_accuracy",
    col="lattice",
    row='alpha',
    kind="line",
    facet_kws=dict(sharex=False, sharey=False),
)
