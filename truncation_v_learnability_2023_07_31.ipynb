# %%
from truncation_v_learnability_2023_07_31 import output_dir
import pandas as pd
import numpy as np
from misc_utils import read_json_dir_to_df
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 2023-08-08 19:25:14.541 | DEBUG    | lattice_symmetries:__init__:50 - Initializing Haskell runtime...
# 2023-08-08 19:25:14.544 | DEBUG    | lattice_symmetries:__init__:52 - Initializing Chapel runtime...
# 2023-08-08 19:25:14.636 | DEBUG    | lattice_symmetries:__init__:54 - Setting Python exception handler...
# set_python_exception_handler ...

# %%
df = read_json_dir_to_df(output_dir)

# %%
df
# Out:
#          loss  train_accuracy  test_accuracy  epoch  run  non_zero_coeffs  \
# 0    3.571141        0.755895       0.685446    299    7             1225
# 1    3.423718        0.771648       0.706647    299    1             1225
# 2    1.860817        0.894688       0.862926    299    2             1488
# 3    2.044185        0.881264       0.842350    299    6              875
# 4    4.420773        0.644540       0.527389    299    7              350
# ..        ...             ...            ...    ...  ...              ...
# 161  1.778673        0.897062       0.854361    299    6             1488
# 162  3.825440        0.727494       0.644498    299    4              875
# 163  1.929060        0.887100       0.848034    299    0             1225
# 164  3.286651        0.781803       0.722752    299    1             1400
# 165  4.034432        0.701209       0.609759    299    4              612
#
#                                                system             lattice  \
# 0    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 1    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 2    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 3    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 4    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# ..                                                ...                 ...
# 161  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 162  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 163  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 164  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 165  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
#
#       J2  keep_terms  split  alpha
# 0    1.3        1225     13  0.001
# 1    1.3        1225     13  0.100
# 2    1.3        1488     16  1.500
# 3    1.3         875      9  1.500
# 4    1.3         350      3  0.001
# ..   ...         ...    ...    ...
# 161  1.3        1488     16  1.500
# 162  1.3         875      9  0.001
# 163  1.3        1225     13  1.500
# 164  1.3        1400     15  0.100
# 165  1.3         612      6  0.001
#
# [166 rows x 12 columns]

# %%
sns.relplot(
    df,
    x="keep_terms",
    y="test_accuracy",
    col="lattice",
    row='alpha',
    kind="line",
    facet_kws=dict(sharex=False, sharey=False),
)
