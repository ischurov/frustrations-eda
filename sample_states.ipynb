# %%
from spin_lattices import KagomeLattice, SquareLattice, SpinLattice
from heisenberg_hamiltonians import HeisenbergJ1J2, SpinSystem
from fourier_supervised_cleanroom import sample_from_system

# %%
lattice = SquareLattice(4, 4)
system_sym = HeisenbergJ1J2(lattice, J1=1, J2=0.5, use_symmetries=True, spin_inversion=None)
system_nosym = HeisenbergJ1J2(lattice, J1=1, J2=0.5, use_symmetries=False, spin_inversion=None)
# Out:
# 2023-10-30 15:36:32.659 | DEBUG    | heisenberg_hamiltonians:__init__:474 - number_spins=16
# 2023-10-30 15:36:32.711 | DEBUG    | heisenberg_hamiltonians:__init__:484 - Symmetry group contains 128 elements
# 2023-10-30 15:36:32.712 | DEBUG    | heisenberg_hamiltonians:__init__:485 - Constructing basis
# 2023-10-30 15:36:32.810 | DEBUG    | heisenberg_hamiltonians:__init__:493 - Hilbert space dimension is 153
# 2023-10-30 15:36:32.825 | DEBUG    | heisenberg_hamiltonians:__init__:474 - number_spins=16
# 2023-10-30 15:36:32.826 | DEBUG    | heisenberg_hamiltonians:__init__:484 - Symmetry group contains 0 elements
# 2023-10-30 15:36:32.827 | DEBUG    | heisenberg_hamiltonians:__init__:485 - Constructing basis
# 2023-10-30 15:36:32.835 | DEBUG    | heisenberg_hamiltonians:__init__:493 - Hilbert space dimension is 12870

# %%
sample_reprs = sample_from_system(system_sym, )
