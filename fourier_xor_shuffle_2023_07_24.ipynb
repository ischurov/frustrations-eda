# %%
import pandas as pd
from fourier_xor_shuffle_2023_07_24 import output_dir
from pathlib import Path
from misc_utils import read_jsonl_to_df
import seaborn as sns

# %%
df = read_jsonl_to_df(output_dir / "output.jsonl")

# %%
df['system']
# Out:
# 0      HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1
# 1      HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1
# 2      HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1
# 3      HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1
# 4      HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1
#                             ...
# 327    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1
# 328    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1
# 329    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1
# 330    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1
# 331    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1
# Name: system, Length: 332, dtype: object

# %%
sns.catplot(
    data=df.query('system == "HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1"'),
    x="transform",
    y="test_accuracy",
    col="non_zero_coeffs",
    col_wrap=2,
    #row="system",
    kind="point",
    order=["identity", "shuffle_xors", "replace_xors_with_random"],
)

# %%
sns.relplot(df.query(
    'system == "HeisenbergJ1J2-SquareLattice6x4-1.0-0.5-True-1" and transform == "replace_xors_with_random"'
), x='non_zero_coeffs', y='test_accuracy', kind='line')

# %%
sns.catplot(
    data=df,
    x="transform",
    y="test_accuracy",
    col="keep",
    row="system",
    kind="swarm",
    order=["identity", "shuffle_xors", "replace_xors_with_random"],
)
# Out:
# /nix/store/810mm036773a280pdrx1k2pqh5pi1mmi-python3-3.10.12-env/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(data=df, x="non_zero_coeffs", y="test_accuracy", hue="transform", row="system", kind='line')
