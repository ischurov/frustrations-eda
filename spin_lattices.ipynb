# %%
from spin_lattices import TriangularLattice
import matplotlib.pyplot as plt

# %%
fig = TriangularLattice(6, 6).plot(
    show_numbers=False,
    swap_axes=False,
    #    size_scale=None,
    #    size_scale_x=3,
    #    size_scale_y=2,
    #    col_wrap=4,
    #show_boundary_conditions=False,
    #color_map={0: "white", 1: "lightgreen"},
    scatter_kws=dict(s=300, edgecolors="black", legend=False),
)
fig.axes.axis("off")
fig.text(0.49, 1.35, "$J_1$")
fig.text(1.03, 1.17, "$J_2$")
plt.savefig("fig/triangular_lattice.pdf", bbox_inches="tight")
#    title_fontsize=20)
