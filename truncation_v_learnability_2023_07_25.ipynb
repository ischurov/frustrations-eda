# %%
from truncation_v_learnability_2023_07_25 import output_dir
import pandas as pd
import numpy as np
from misc_utils import read_json_dir_to_df
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 2023-07-26 11:20:20.197 | DEBUG    | lattice_symmetries:__init__:50 - Initializing Haskell runtime...
# 2023-07-26 11:20:20.199 | DEBUG    | lattice_symmetries:__init__:52 - Initializing Chapel runtime...
# 2023-07-26 11:20:20.220 | DEBUG    | lattice_symmetries:__init__:54 - Setting Python exception handler...
# set_python_exception_handler ...

# %%
df = read_json_dir_to_df(output_dir)

# %%
df
# Out:
#          loss  train_accuracy  test_accuracy  epoch  run  non_zero_coeffs  \
# 0    0.049299        0.993048       0.715637    299    7             1225
# 1    0.316972        0.908032       0.503367    299    7             6911
# 2    0.053734        0.992308       0.720241    299    1             1225
# 3    0.059064        0.991569       0.711022    299    2             1488
# 4    0.079738        0.986207       0.689795    299    6              875
# ..        ...             ...            ...    ...  ...              ...
# 319  0.337996        0.902300       0.500346    299    4            10367
# 320  0.064195        0.990681       0.697594    299    1             1400
# 321  0.095735        0.982213       0.671294    299    4              612
# 322  0.321667        0.906072       0.504558    299    6             5759
# 323  0.312211        0.907921       0.504417    299    6             2303
#
#                                                system             lattice  \
# 0    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 1      HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1    KagomeLattice2x4
# 2    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 3    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 4    HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# ..                                                ...                 ...
# 319    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1    KagomeLattice2x4
# 320  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 321  HeisenbergJ1J2-TriangleLattice6x4-1.0-1.3-True-1  TriangleLattice6x4
# 322    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1    KagomeLattice2x4
# 323    HeisenbergJ1J2-KagomeLattice2x4-1.0-1.0-True-1    KagomeLattice2x4
#
#       J2  keep_terms  split
# 0    1.3        1225     13
# 1    1.0        6911      5
# 2    1.3        1225     13
# 3    1.3        1488     16
# 4    1.3         875      9
# ..   ...         ...    ...
# 319  1.0       10367      8
# 320  1.3        1400     15
# 321  1.3         612      6
# 322  1.0        5759      4
# 323  1.0        2303      1
#
# [324 rows x 11 columns]

# %%
sns.relplot(
    df,
    x="keep_terms",
    y="test_accuracy",
    col="lattice",
    kind="line",
    facet_kws=dict(sharex=False, sharey=False),
)
