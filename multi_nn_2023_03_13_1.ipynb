# %%
import json
from itertools import product
from pathlib import Path

import numpy as np
import numpy.typing as npt
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data
from loguru import logger
from torchmetrics.classification import BinaryF1Score
from tqdm import tqdm

from fast_boolean_analysis import FourierSeries, fourier_expand
from heisenberg_hamiltonians import HeisenbergJ1J2, SpinSystem
from lattice_boolean_analysis import (
    AmplitudeSignalKind,
    AmplitudeMedianBinSignalKind,
    LBFFromNN,
    LBFFromSpinSystem,
    SignalKind,
    SignSignalKind,
)
from pytorchtools import EarlyStopping
from spin_lattices import KagomeLattice, SpinLattice, SquareLattice, TriangleLattice
from spin_nn import FC1SpinNN, SpinNN
from utils import get_abslargest_terms, make_unpacked_configurations
from multi_nn_2023_03_14_1 import (
    ground_state_cache_dir,
    experiment_dir,
    nn_checkpoints_dir,
    model_evaluation_dir,
    nn_terms_dir,
    system_terms_dir,
    eps_trains,
    J2s,
    signal_kinds,
    lattices,
)
import seaborn as sns

# %%
# %matplotlib inline

# %%
def json_dir_to_df(dir: Path) -> pd.DataFrame:
    return pd.DataFrame([json.loads(file.read_text()) for file in dir.glob("*")])


name_to_lattice = {lattice.get_cache_id(): lattice for lattice in lattices}

# %%
model_evaluation = json_dir_to_df(model_evaluation_dir)
nn_terms = json_dir_to_df(nn_terms_dir)
system_terms = json_dir_to_df(system_terms_dir)

# %%
model_evaluation.groupby([''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model_evaluation.groupby([''])
#
# File /vol/tcm10/ischurov/.conda/envs/latsym2/lib/python3.10/site-packages/pandas/core/frame.py:8298, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8295     raise TypeError("You have to supply one of 'by' and 'level'")
#    8296 axis = self._get_axis_number(axis)
# -> 8298 return DataFrameGroupBy(
#    8299     obj=self,
#    8300     keys=by,
#    8301     axis=axis,
#    8302     level=level,
#    8303     as_index=as_index,
#    8304     sort=sort,
#    8305     group_keys=group_keys,
#    8306     squeeze=squeeze,
#    8307     observed=observed,
#    8308     dropna=dropna,
#    8309 )
#
# File /vol/tcm10/ischurov/.conda/envs/latsym2/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File /vol/tcm10/ischurov/.conda/envs/latsym2/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: ''

# %%
sns.relplot(
    model_evaluation.drop(["path", "signal_kind", "train_size"], axis=1)
    .melt(id_vars=["lattice", "J2", "eps_train", "epoch", "net_id"])
    .query('variable.str.startswith("accuracy")').sort_values("net_id"),
    x="epoch",
    hue="variable",
    y="value",
    kind="line",
    col="J2",
    row="net_id",
)

# %%
system_terms.query("lattice == 'KagomeLattice2x4'")[
            "iipr_hamming_no_free_term"
        ]
# Out:
# 0       272.562495
# 1    671513.668838
# Name: iipr_hamming_no_free_term, dtype: float64

# %%
g = sns.relplot(
    nn_terms.sort_values("net_id"),
    x="epoch",
    y="iipr_hamming",
    row="net_id",
    col="J2",
    kind="line",
).set(yscale="log")

for row in g.axes:
    for ax, J2 in zip(row, [0.5, 0.6]):
        ground_true = system_terms.query("lattice == 'KagomeLattice2x4' and J2 == @J2").iloc[0][
            "iipr_hamming_no_free_term"
        ]
        ax.axhline(ground_true, color="red", linestyle="--")
