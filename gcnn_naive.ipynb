# %%
from gcnn_naive import GConvG
from sympy.combinatorics import Permutation
from spin_lattices import SquareLattice
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 100000

lattice = SquareLattice(6, 6)
group = [Permutation(g) for g in lattice.get_automorphisms()]
layer = GConvG(
    group_elements=group,
    filter_idxs=[0, 1, 5, 7],
    in_channels=20,
    out_channels=30,
).to(device)

x = torch.randn(batch_size, 20, len(group)).to(device)

# %%
# %%timeit
result = layer.forward(x)
# print(f"{result.shape=}, {result=}")
# Out:
# 716 ms ± 1.64 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
result2 = layer.forward_matmul(x)
# print(f"{result2.shape=}, {result2=}")
# Out:
# 734 ms ± 3.21 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
